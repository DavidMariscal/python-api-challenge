# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import citipy
from scipy.stats import linregress
from datetime import datetime


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

from ratelimiter import RateLimiter

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
set_counter = 0
record_counter = 0
Cloud = []
Country = []
Date = []
Humidity = []
Temp = []
Lati = []
Longi = []
Wind = []
Unique_Cities = []

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
  # with rate_limiter:  
     query_url = url + "&q=" + city
     # Get weather data
     response = requests.get(query_url).json()
     if record_counter < 50:
      record_counter += 1
     else:
        set_counter += 1
        record_counter = 0

     print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
     print(url)
       
     try:
         Cloud.append(response['clouds']['all'])
         Country.append(response['sys']['country'])
         Date.append(response['dt'])
         Humidity.append(response['main']['humidity'])
         Temp.append(response['main']['temp_max'])
         Lati.append(response['coord']['lat'])
         Longi.append(response['coord']['lon'])
         Wind.append(response['wind']['speed'])
         Unique_Cities.append(city)
      
     except:
         print("City not found!")
         pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | bria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 2 of set 0 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 3 of set 0 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 4 of set 0 | aleksandrovsk-sakhalinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 5 of set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 6 of set 0 | buenavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 7 of set 0 | klintsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 8 of set 0 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 9 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 10 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 11 of set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 12 of set 0 | uarini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 13 of set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 14 of set 0 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 15 of set 0 | kaura namoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 16 of set 0 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 17 of set 0 | provost
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 18 of set 0 | auly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 19 of set 0 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 20 of set 0 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 21 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 22 of set 0 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 23 of set 0 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 24 of set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 25 of set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 26 of set 0 | pucallpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 27 of set 0 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 28 of set 0 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 29 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 30 of set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 31 of set 0 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 32 of set 0 | weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 33 of set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 34 of set 0 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 35 of set 0 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 36 of set 0 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 37 of set 0 | dandong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 38 of set 0 | kaputa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 39 of set 0 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 40 of set 0 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 41 of set 0 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 42 of set 0 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 43 of set 0 | susanville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 44 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 45 of set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 46 of set 0 | altoona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 47 of set 0 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 48 of set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 49 of set 0 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 50 of set 0 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 0 of set 1 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 1 of set 1 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 2 of set 1 | kouango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 3 of set 1 | glenwood springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 4 of set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 5 of set 1 | envira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 6 of set 1 | sivaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 7 of set 1 | goure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 8 of set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 9 of set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 10 of set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 11 of set 1 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 12 of set 1 | alto vera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 13 of set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 14 of set 1 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 15 of set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 16 of set 1 | banepa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 17 of set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 18 of set 1 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 19 of set 1 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 20 of set 1 | iroquois falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 21 of set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 22 of set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 23 of set 1 | port antonio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 24 of set 1 | barreirinha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 25 of set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 26 of set 1 | kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 27 of set 1 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 28 of set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 29 of set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 30 of set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 31 of set 1 | rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 32 of set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 33 of set 1 | taft
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 34 of set 1 | dutlwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 35 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 36 of set 1 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 37 of set 1 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 38 of set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 39 of set 1 | dong hoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 40 of set 1 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 41 of set 1 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 42 of set 1 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 43 of set 1 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 44 of set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 45 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 46 of set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 47 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 48 of set 1 | yamethin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 49 of set 1 | port-de-paix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 50 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 0 of set 2 | dilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 1 of set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record
ng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 34 of set 10 | tignere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 35 of set 10 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 36 of set 10 | dalby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 37 of set 10 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 38 of set 10 | pafos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 39 of set 10 | sunrise manor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 40 of set 10 | zelenogorskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 41 of set 10 | ihosy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 42 of set 10 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 43 of set 10 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 44 of set 10 | longkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 45 of set 10 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 46 of set 10 | calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 47 of set 10 | baoqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 48 of set 10 | quyquyho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 49 of set 10 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 50 of set 10 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 0 of set 11 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 1 of set 11 | siva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 2 of set 11 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 3 of set 11 | amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 4 of set 11 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 5 of set 11 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 6 of set 11 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 7 of set 11 | kauhajoki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 8 of set 11 | januaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 9 of set 11 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 10 of set 11 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 11 of set 11 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 12 of set 11 | krivosheino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 13 of set 11 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 14 of set 11 | vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 15 of set 11 | gien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 16 of set 11 | vanino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 17 of set 11 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 18 of set 11 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 19 of set 11 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 20 of set 11 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 21 of set 11 | dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 22 of set 11 | kinshasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 23 of set 11 | neepawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 24 of set 11 | kingman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 25 of set 11 | yanchukan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 26 of set 11 | narrabri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 27 of set 11 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 28 of set 11 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 29 of set 11 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 30 of set 11 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 31 of set 11 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 32 of set 11 | dom pedrito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 33 of set 11 | lanquin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 34 of set 11 | pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 35 of set 11 | mirabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 36 of set 11 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 37 of set 11 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 38 of set 11 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 39 of set 11 | dien bien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# City not found!
# Processing record 40 of set 11 | ust-uda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 41 of set 11 | vallenar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 42 of set 11 | alta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 43 of set 11 | ferrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 44 of set 11 | kuopio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 45 of set 11 | tonantins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 46 of set 11 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 47 of set 11 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 48 of set 11 | yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 49 of set 11 | normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 50 of set 11 | montreux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 0 of set 12 | sao bernardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 1 of set 12 | oriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 2 of set 12 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 3 of set 12 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 4 of set 12 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 5 of set 12 | rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 6 of set 12 | msanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 7 of set 12 | pontal do parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 8 of set 12 | catamarca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 9 of set 12 | carnot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 10 of set 12 | ardahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 11 of set 12 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 12 of set 12 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# Processing record 13 of set 12 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=13f3dd809f7bb0ef4105ffa8aa3e0d8e
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
Weather_Raw_Data = {
    "City": Unique_Cities,
    "Cloudiness" : Cloud,
    "Country" : Country,
    "Date" : Date,
    "Humidity" : Humidity,
    "Temp": Temp,
    "Lat" : Lati,
    "Lng" : Longi,   
    "Wind Speed" : Wind
}
Weather_df = pd.DataFrame(Weather_Raw_Data)
Weather_df.head()
# Out:
#                          City  Cloudiness Country        Date  Humidity  \
# 0                        bria          95      CF  1579757173        21
# 1                   raudeberg          75      NO  1579757173       100
# 2                san jeronimo         100      PE  1579757173        91
# 3  aleksandrovsk-sakhalinskiy          23      RU  1579757173        92
# 4                 port alfred          91      ZA  1579757173        95
#
#     Temp    Lat     Lng  Wind Speed
# 0  63.88   6.54   21.99        9.19
# 1  46.40  61.99    5.14       19.46
# 2  42.64 -11.95  -75.28        0.56
# 3  -0.72  50.90  142.16        1.79
# 4  64.99 -33.59   26.89       12.15

# %%
# output_file = os.path.join('output_data', 'cities.csv')
# with open(output_file, 'w') as datafile:
    Weather_df.to_csv('cities.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
date = datetime.now()
date = date.strftime("%m-%d-%Y")

plt.scatter(Weather_df["Lat"], Weather_df["Temp"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Temperature ($^\circ$F)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(Weather_df["Lat"], Weather_df["Humidity"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Humidity ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Humidity (%)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(Weather_df["Lat"], Weather_df["Cloudiness"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Cloudiness (%)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("Clouds.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(Weather_df["Lat"], Weather_df["Wind Speed"], alpha=.75, edgecolors="k")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude ($^\circ$)")
plt.ylabel("Wind Speed (MPH)")
plt.grid(True) 
plt.tight_layout()
plt.savefig("Wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def Linear_Regression_Plot(Param1, Param2, Title, XLabel, YLabel, Ann_X, Ann_Y):
    x_values = Param1
    y_values = Param2
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(Ann_X,Ann_Y),fontsize=15,color="red")
    plt.title(Title, fontsize=16, fontweight="bold")
    plt.xlabel(XLabel)
    plt.ylabel(YLabel)
    return plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
South_Hemisphere =Weather_df.loc[Weather_df["Lat"] > 0, :]
North_Hemisphere =Weather_df.loc[Weather_df["Lat"] <= 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(North_Hemisphere['Temp'], North_Hemisphere['Lat'], "Northern Hemisphere", "Max Temp", "Latitude", 55, -40)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(South_Hemisphere['Temp'], South_Hemisphere['Lat'], "Southern Hemisphere", "Max Temp", "Latitude", -40, 25)

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(North_Hemisphere['Humidity'], North_Hemisphere['Lat'], "Northern Hemisphere", "Humidity (%)", "Latitude", 25, -40)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(South_Hemisphere['Humidity'], South_Hemisphere['Lat'], "Southern Hemisphere", "Humidity (%)", "Latitude", 20, 40)

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(North_Hemisphere['Cloudiness'], North_Hemisphere['Lat'], "Northern Hemisphere", "Cloudiness (%)", "Latitude", 40, -30)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(South_Hemisphere['Cloudiness'], South_Hemisphere['Lat'], "Southern Hemisphere", "Cloudiness (%)", "Latitude", 20, 40)

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(North_Hemisphere['Wind Speed'], North_Hemisphere['Lat'], "Northern Hemisphere", "Wind Speed (mph)", "Latitude", 40, -30)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Linear_Regression_Plot(South_Hemisphere['Wind Speed'], South_Hemisphere['Lat'], "Southern Hemisphere", "Wind Speed (mph)", "Latitude", 20, 40)
